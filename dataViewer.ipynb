# %%
import pandas as pd
import codecs

# %%
with codecs.open("./OriginData/poi_101.csv", mode="r", encoding="shift_jis",errors="ignore") as file:
    data = pd.read_csv(file)
data
# Out:
#                      zid             zid_attr                   id  \
# 0     309098570781342979  1749746353375807561   309098570781342979
# 1     309495494478999811  1751686991398837400   309495494478999811
# 2     306408065828160089  1748440133562643062   306408065828160089
# 3    1750100917958483399  1750100396119956936  1750100917958483399
# 4    1751045398446956522  1751044876608430108  1751045398446956522
# ..                   ...                  ...                  ...
# 182  1750678168005617734                    1  1750678168005617734
# 183  1751013519052094798                    1  1751013519052094798
# 184  1750678168005617726                    1  1750678168005617726
# 185  1750678168005617764                    1  1750678168005617764
# 186  1750678168005617750                    1  1750678168005617750
#
#                  id_attr building_name                 name name_read  \
# 0    1749746353375807561           NaN                 上林公園       NaN
# ...
